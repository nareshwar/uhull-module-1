# %% [markdown]
# ### Task 1

# %% [markdown]
# #### Importing Pandas

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### Load CSV into Pandas

# %%
ss_data = pd.read_csv('sample-superstore-2023-T3.csv')

# %% [markdown]
# #### Load first 10 records

# %%
first_10_rows = ss_data.head(n=10)
first_10_rows
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0    7773  CA-2016-108196  25/11/2016  12/02/2016  Standard Class    CS-12505
# 1     684  US-2017-168116  11/04/2017  11/04/2017        Same Day    GT-14635
# 2    9775  CA-2014-169019  26/07/2014  30/07/2014  Standard Class    LF-17185
# 3    3012  CA-2017-134845  17/04/2017  24/04/2017  Standard Class    SR-20425
# 4    4992  US-2017-122714  12/07/2017  13/12/2017  Standard Class    HG-14965
# 5    3152  CA-2015-147830  15/12/2015  18/12/2015     First Class    NF-18385
# 6    5311  CA-2017-131254  19/11/2017  21/11/2017     First Class    NC-18415
# 7    9640  CA-2015-116638  28/01/2015         NaN    Second Class    JH-15985
# 8    1200  CA-2016-130946  04/08/2016  04/12/2016  Standard Class    ZC-21910
# 9    2698  CA-2014-145317  18/03/2014  23/03/2014  Standard Class    SM-20320
#
#       Customer Name      Segment        Country          City           State  \
# 0     Cindy Stewart     Consumer  United States     Lancaster            Ohio
# 1    Grant Thornton    Corporate  United States    Burlington  North Carolina
# 2       Luke Foster     Consumer  United States   San Antonio           Texas
# 3    Sharelle Roach  Home Office  United States    Louisville        Colorado
# 4     Henry Goldwyn    Corporate  United States       Chicago        Illinois
# 5  Natalie Fritzler     Consumer  United States        Newark            Ohio
# 6       Nathan Cano     Consumer  United States       Houston           Texas
# 7       Joseph Holt     Consumer  United States       Concord  North Carolina
# 8  Zuschuss Carroll     Consumer  United States       Houston           Texas
# 9       Sean Miller  Home Office            NaN  Jacksonville         Florida
#
#   Postal Code   Region       Product ID         Category Sub-Category  \
# 0       43130      Est  TEC-MA-10000418       Technology     Machines
# 1     "27217"    South  TEC-MA-10004125       Technology     Machines
# 2       78207  Central  OFF-BI-10004995  Office Supplies      Binders
# 3       80027     West  TEC-MA-10000822       Technology     Machines
# 4       60653  Central  OFF-BI-10001120  Office Supplies      Binders
# 5       43055     East  TEC-MA-10000418       Technology     Machines
# 6       77095  Central  OFF-BI-10003527  Office Supplies      Binders
# 7       28027    South  FUR-TA-10000198          Frnture       Tables
# 8       77041  Central  OFF-BI-10004995  Office Supplies      Binders
# 9       32216   Southh  TEC-MA-10002412       Technology     Machines
#
#                                         Product Name      Sales  Quantity  \
# 0          Cubify CubeX 3D Printer Double Head Print   4499.985         5
# 1          Cubify CubeX 3D Printer Triple Head Print   7999.980         4
# 2          GBC DocuBind P400 Electric Binding System   2177.584         8
# 3          Lexmark MX611dhe Monochrome Laser Printer   2549.985         5
# 4               Ibico EPK-21 Electric Binding System   1889.990         5
# 5          Cubify CubeX 3D Printer Double Head Print   1799.994       Two
# 6  Fellowes PB500 Electric Punch Plastic Comb Bin...   1525.188         6
# 7  Chromcraft Bull-Nose Wood Oval Conference Tabl...   4297.644  Thirteen
# 8          GBC DocuBind P400 Electric Binding System   1088.792         4
# 9  Cisco TelePresence System EX90 Videoconferenci...  22638.480         6
#
#    Discount        Profit
# 0       0.7     -6599.978
# 1       0.5    -3839.9904
# 2       0.8    -3701.8928
# 3       0.7      -3399.98
# 4       0.8    -2929.4845
# 5       0.7  "-2639.9912"
# 6       0.8     -2287.782
# 7       0.4           NaN
# 8       0.8    -1850.9464
# 9       0.5    -1811.0784

# %% [markdown]
# Using info() and describe() function to get the descriptive statistics

# %%
first_10_rows.info()

columns_to_describe = first_10_rows.drop(columns=['Row ID'])
columns_to_describe

columns_to_describe.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         10 non-null     int64
#  1   Order ID       10 non-null     object
#  2   Order Date     10 non-null     object
#  3   Ship Date      9 non-null      object
#  4   Ship Mode      10 non-null     object
#  5   Customer ID    10 non-null     object
#  6   Customer Name  10 non-null     object
#  7   Segment        10 non-null     object
#  8   Country        9 non-null      object
#  9   City           10 non-null     object
#  10  State          10 non-null     object
#  11  Postal Code    10 non-null     object
#  12  Region         10 non-null     object
#  13  Product ID     10 non-null     object
#  14  Category       10 non-null     object
#  15  Sub-Category   10 non-null     object
#  16  Product Name   10 non-null     object
#  17  Sales          10 non-null     float64
#  18  Quantity       10 non-null     object
#  19  Discount       10 non-null     float64
#  20  Profit         9 non-null      object
# dtypes: float64(2), int64(1), object(18)
# memory usage: 1.8+ KB
#               Sales   Discount
# count     10.000000  10.000000
# mean    5046.762200   0.670000
# std     6515.707357   0.149443
# min     1088.792000   0.400000
# 25%     1822.493000   0.550000
# 50%     2363.784500   0.700000
# 75%     4449.399750   0.800000
# max    22638.480000   0.800000

# %% [markdown]
# The primary key of these records are RowID, most likely a system generated unique int64 value.
#
# The datatypes of the dataset are following:
# * int64(1)
# * float64(2)
# * object(18)
#
# A few records of *Quantity* and *Profit* columns has the datatype of object, but it must be float64, thus needs to be cleansed or transformed.
#
# The descriptive statistics can be applied to the numerial columns, and they are Sales, Quantity, Discount and Profit.
# The summary could be applied to categorical columns: Order Date, Ship Date, Ship Mode, Segment, Country, City, State, Postal Code, Region, Category, Sub-Category, and Product Name.

# %% [markdown]
# #### Function to convert the text to a float

# %%
def text2float(textnum, numwords={}):
    try:
        # Attempt to convert to float
        return float(textnum)
    except ValueError:
        # If conversion to float fails, continue with text to number conversion
        textnum = textnum.lower()
        
        if not numwords:
            units = [
                "zero", "one", "two", "three", "four", "five", "six", "seven", "eight",
                "nine", "ten", "eleven", "twelve", "thirteen", "fourteen", "fifteen",
                "sixteen", "seventeen", "eighteen", "nineteen",
            ]

            tens = ["", "", "twenty", "thirty", "forty", "fifty", "sixty", "seventy", "eighty", "ninety"]

            scales = ["hundred", "thousand", "million", "billion", "trillion"]

            numwords["and"] = (1, 0)
            for idx, word in enumerate(units):
                numwords[word] = (1, idx)
            for idx, word in enumerate(tens):
                numwords[word] = (1, idx * 10)
            for idx, word in enumerate(scales):
                numwords[word] = (10 ** (idx * 3 or 2), 0)

        current = result = 0
        for word in textnum.split():
            if word not in numwords:
                raise Exception("Illegal word: " + word)

            scale, increment = numwords[word]
            current = current * scale + increment
            if scale > 100:
                result += current
                current = 0

        return result + current

# %%
columns_to_describe['Profit'] = columns_to_describe['Profit'].fillna(0)
columns_to_describe
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-108196  25/11/2016  12/02/2016  Standard Class    CS-12505
# 1  US-2017-168116  11/04/2017  11/04/2017        Same Day    GT-14635
# 2  CA-2014-169019  26/07/2014  30/07/2014  Standard Class    LF-17185
# 3  CA-2017-134845  17/04/2017  24/04/2017  Standard Class    SR-20425
# 4  US-2017-122714  12/07/2017  13/12/2017  Standard Class    HG-14965
# 5  CA-2015-147830  15/12/2015  18/12/2015     First Class    NF-18385
# 6  CA-2017-131254  19/11/2017  21/11/2017     First Class    NC-18415
# 7  CA-2015-116638  28/01/2015         NaN    Second Class    JH-15985
# 8  CA-2016-130946  04/08/2016  04/12/2016  Standard Class    ZC-21910
# 9  CA-2014-145317  18/03/2014  23/03/2014  Standard Class    SM-20320
#
#       Customer Name      Segment        Country          City           State  \
# 0     Cindy Stewart     Consumer  United States     Lancaster            Ohio
# 1    Grant Thornton    Corporate  United States    Burlington  North Carolina
# 2       Luke Foster     Consumer  United States   San Antonio           Texas
# 3    Sharelle Roach  Home Office  United States    Louisville        Colorado
# 4     Henry Goldwyn    Corporate  United States       Chicago        Illinois
# 5  Natalie Fritzler     Consumer  United States        Newark            Ohio
# 6       Nathan Cano     Consumer  United States       Houston           Texas
# 7       Joseph Holt     Consumer  United States       Concord  North Carolina
# 8  Zuschuss Carroll     Consumer  United States       Houston           Texas
# 9       Sean Miller  Home Office            NaN  Jacksonville         Florida
#
#   Postal Code   Region       Product ID         Category Sub-Category  \
# 0       43130      Est  TEC-MA-10000418       Technology     Machines
# 1     "27217"    South  TEC-MA-10004125       Technology     Machines
# 2       78207  Central  OFF-BI-10004995  Office Supplies      Binders
# 3       80027     West  TEC-MA-10000822       Technology     Machines
# 4       60653  Central  OFF-BI-10001120  Office Supplies      Binders
# 5       43055     East  TEC-MA-10000418       Technology     Machines
# 6       77095  Central  OFF-BI-10003527  Office Supplies      Binders
# 7       28027    South  FUR-TA-10000198          Frnture       Tables
# 8       77041  Central  OFF-BI-10004995  Office Supplies      Binders
# 9       32216   Southh  TEC-MA-10002412       Technology     Machines
#
#                                         Product Name      Sales  Quantity  \
# 0          Cubify CubeX 3D Printer Double Head Print   4499.985         5
# 1          Cubify CubeX 3D Printer Triple Head Print   7999.980         4
# 2          GBC DocuBind P400 Electric Binding System   2177.584         8
# 3          Lexmark MX611dhe Monochrome Laser Printer   2549.985         5
# 4               Ibico EPK-21 Electric Binding System   1889.990         5
# 5          Cubify CubeX 3D Printer Double Head Print   1799.994       Two
# 6  Fellowes PB500 Electric Punch Plastic Comb Bin...   1525.188         6
# 7  Chromcraft Bull-Nose Wood Oval Conference Tabl...   4297.644  Thirteen
# 8          GBC DocuBind P400 Electric Binding System   1088.792         4
# 9  Cisco TelePresence System EX90 Videoconferenci...  22638.480         6
#
#    Discount        Profit
# 0       0.7     -6599.978
# 1       0.5    -3839.9904
# 2       0.8    -3701.8928
# 3       0.7      -3399.98
# 4       0.8    -2929.4845
# 5       0.7  "-2639.9912"
# 6       0.8     -2287.782
# 7       0.4             0
# 8       0.8    -1850.9464
# 9       0.5    -1811.0784

# %%
columns_to_describe['Quantity'] = columns_to_describe['Quantity'].apply(text2float)
columns_to_describe
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-108196  25/11/2016  12/02/2016  Standard Class    CS-12505
# 1  US-2017-168116  11/04/2017  11/04/2017        Same Day    GT-14635
# 2  CA-2014-169019  26/07/2014  30/07/2014  Standard Class    LF-17185
# 3  CA-2017-134845  17/04/2017  24/04/2017  Standard Class    SR-20425
# 4  US-2017-122714  12/07/2017  13/12/2017  Standard Class    HG-14965
# 5  CA-2015-147830  15/12/2015  18/12/2015     First Class    NF-18385
# 6  CA-2017-131254  19/11/2017  21/11/2017     First Class    NC-18415
# 7  CA-2015-116638  28/01/2015         NaN    Second Class    JH-15985
# 8  CA-2016-130946  04/08/2016  04/12/2016  Standard Class    ZC-21910
# 9  CA-2014-145317  18/03/2014  23/03/2014  Standard Class    SM-20320
#
#       Customer Name      Segment        Country          City           State  \
# 0     Cindy Stewart     Consumer  United States     Lancaster            Ohio
# 1    Grant Thornton    Corporate  United States    Burlington  North Carolina
# 2       Luke Foster     Consumer  United States   San Antonio           Texas
# 3    Sharelle Roach  Home Office  United States    Louisville        Colorado
# 4     Henry Goldwyn    Corporate  United States       Chicago        Illinois
# 5  Natalie Fritzler     Consumer  United States        Newark            Ohio
# 6       Nathan Cano     Consumer  United States       Houston           Texas
# 7       Joseph Holt     Consumer  United States       Concord  North Carolina
# 8  Zuschuss Carroll     Consumer  United States       Houston           Texas
# 9       Sean Miller  Home Office            NaN  Jacksonville         Florida
#
#   Postal Code   Region       Product ID         Category Sub-Category  \
# 0       43130      Est  TEC-MA-10000418       Technology     Machines
# 1     "27217"    South  TEC-MA-10004125       Technology     Machines
# 2       78207  Central  OFF-BI-10004995  Office Supplies      Binders
# 3       80027     West  TEC-MA-10000822       Technology     Machines
# 4       60653  Central  OFF-BI-10001120  Office Supplies      Binders
# 5       43055     East  TEC-MA-10000418       Technology     Machines
# 6       77095  Central  OFF-BI-10003527  Office Supplies      Binders
# 7       28027    South  FUR-TA-10000198          Frnture       Tables
# 8       77041  Central  OFF-BI-10004995  Office Supplies      Binders
# 9       32216   Southh  TEC-MA-10002412       Technology     Machines
#
#                                         Product Name      Sales  Quantity  \
# 0          Cubify CubeX 3D Printer Double Head Print   4499.985       5.0
# 1          Cubify CubeX 3D Printer Triple Head Print   7999.980       4.0
# 2          GBC DocuBind P400 Electric Binding System   2177.584       8.0
# 3          Lexmark MX611dhe Monochrome Laser Printer   2549.985       5.0
# 4               Ibico EPK-21 Electric Binding System   1889.990       5.0
# 5          Cubify CubeX 3D Printer Double Head Print   1799.994       2.0
# 6  Fellowes PB500 Electric Punch Plastic Comb Bin...   1525.188       6.0
# 7  Chromcraft Bull-Nose Wood Oval Conference Tabl...   4297.644      13.0
# 8          GBC DocuBind P400 Electric Binding System   1088.792       4.0
# 9  Cisco TelePresence System EX90 Videoconferenci...  22638.480       6.0
#
#    Discount        Profit
# 0       0.7     -6599.978
# 1       0.5    -3839.9904
# 2       0.8    -3701.8928
# 3       0.7      -3399.98
# 4       0.8    -2929.4845
# 5       0.7  "-2639.9912"
# 6       0.8     -2287.782
# 7       0.4             0
# 8       0.8    -1850.9464
# 9       0.5    -1811.0784

# %%
columns_to_describe.describe()
# Out:
#               Sales   Quantity   Discount
# count     10.000000  10.000000  10.000000
# mean    5046.762200   5.800000   0.670000
# std     6515.707357   2.973961   0.149443
# min     1088.792000   2.000000   0.400000
# 25%     1822.493000   4.250000   0.550000
# 50%     2363.784500   5.000000   0.700000
# 75%     4449.399750   6.000000   0.800000
# max    22638.480000  13.000000   0.800000

# %%
columns_to_describe['Profit'] = columns_to_describe['Profit'].str.replace('"','')
columns_to_describe['Profit'] = columns_to_describe['Profit'].fillna(0)
columns_to_describe
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-108196  25/11/2016  12/02/2016  Standard Class    CS-12505
# 1  US-2017-168116  11/04/2017  11/04/2017        Same Day    GT-14635
# 2  CA-2014-169019  26/07/2014  30/07/2014  Standard Class    LF-17185
# 3  CA-2017-134845  17/04/2017  24/04/2017  Standard Class    SR-20425
# 4  US-2017-122714  12/07/2017  13/12/2017  Standard Class    HG-14965
# 5  CA-2015-147830  15/12/2015  18/12/2015     First Class    NF-18385
# 6  CA-2017-131254  19/11/2017  21/11/2017     First Class    NC-18415
# 7  CA-2015-116638  28/01/2015         NaN    Second Class    JH-15985
# 8  CA-2016-130946  04/08/2016  04/12/2016  Standard Class    ZC-21910
# 9  CA-2014-145317  18/03/2014  23/03/2014  Standard Class    SM-20320
#
#       Customer Name      Segment        Country          City           State  \
# 0     Cindy Stewart     Consumer  United States     Lancaster            Ohio
# 1    Grant Thornton    Corporate  United States    Burlington  North Carolina
# 2       Luke Foster     Consumer  United States   San Antonio           Texas
# 3    Sharelle Roach  Home Office  United States    Louisville        Colorado
# 4     Henry Goldwyn    Corporate  United States       Chicago        Illinois
# 5  Natalie Fritzler     Consumer  United States        Newark            Ohio
# 6       Nathan Cano     Consumer  United States       Houston           Texas
# 7       Joseph Holt     Consumer  United States       Concord  North Carolina
# 8  Zuschuss Carroll     Consumer  United States       Houston           Texas
# 9       Sean Miller  Home Office            NaN  Jacksonville         Florida
#
#   Postal Code   Region       Product ID         Category Sub-Category  \
# 0       43130      Est  TEC-MA-10000418       Technology     Machines
# 1     "27217"    South  TEC-MA-10004125       Technology     Machines
# 2       78207  Central  OFF-BI-10004995  Office Supplies      Binders
# 3       80027     West  TEC-MA-10000822       Technology     Machines
# 4       60653  Central  OFF-BI-10001120  Office Supplies      Binders
# 5       43055     East  TEC-MA-10000418       Technology     Machines
# 6       77095  Central  OFF-BI-10003527  Office Supplies      Binders
# 7       28027    South  FUR-TA-10000198          Frnture       Tables
# 8       77041  Central  OFF-BI-10004995  Office Supplies      Binders
# 9       32216   Southh  TEC-MA-10002412       Technology     Machines
#
#                                         Product Name      Sales  Quantity  \
# 0          Cubify CubeX 3D Printer Double Head Print   4499.985       5.0
# 1          Cubify CubeX 3D Printer Triple Head Print   7999.980       4.0
# 2          GBC DocuBind P400 Electric Binding System   2177.584       8.0
# 3          Lexmark MX611dhe Monochrome Laser Printer   2549.985       5.0
# 4               Ibico EPK-21 Electric Binding System   1889.990       5.0
# 5          Cubify CubeX 3D Printer Double Head Print   1799.994       2.0
# 6  Fellowes PB500 Electric Punch Plastic Comb Bin...   1525.188       6.0
# 7  Chromcraft Bull-Nose Wood Oval Conference Tabl...   4297.644      13.0
# 8          GBC DocuBind P400 Electric Binding System   1088.792       4.0
# 9  Cisco TelePresence System EX90 Videoconferenci...  22638.480       6.0
#
#    Discount      Profit
# 0       0.7   -6599.978
# 1       0.5  -3839.9904
# 2       0.8  -3701.8928
# 3       0.7    -3399.98
# 4       0.8  -2929.4845
# 5       0.7  -2639.9912
# 6       0.8   -2287.782
# 7       0.4           0
# 8       0.8  -1850.9464
# 9       0.5  -1811.0784

# %%
columns_to_describe.describe()
columns_to_describe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       10 non-null     object
#  1   Order Date     10 non-null     object
#  2   Ship Date      9 non-null      object
#  3   Ship Mode      10 non-null     object
#  4   Customer ID    10 non-null     object
#  5   Customer Name  10 non-null     object
#  6   Segment        10 non-null     object
#  7   Country        9 non-null      object
#  8   City           10 non-null     object
#  9   State          10 non-null     object
#  10  Postal Code    10 non-null     object
#  11  Region         10 non-null     object
#  12  Product ID     10 non-null     object
#  13  Category       10 non-null     object
#  14  Sub-Category   10 non-null     object
#  15  Product Name   10 non-null     object
#  16  Sales          10 non-null     float64
#  17  Quantity       10 non-null     float64
#  18  Discount       10 non-null     float64
#  19  Profit         10 non-null     object
# dtypes: float64(3), object(17)
# memory usage: 1.7+ KB

# %%
columns_to_describe['Profit'] = columns_to_describe['Profit'].apply(text2float)
columns_to_describe
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-108196  25/11/2016  12/02/2016  Standard Class    CS-12505
# 1  US-2017-168116  11/04/2017  11/04/2017        Same Day    GT-14635
# 2  CA-2014-169019  26/07/2014  30/07/2014  Standard Class    LF-17185
# 3  CA-2017-134845  17/04/2017  24/04/2017  Standard Class    SR-20425
# 4  US-2017-122714  12/07/2017  13/12/2017  Standard Class    HG-14965
# 5  CA-2015-147830  15/12/2015  18/12/2015     First Class    NF-18385
# 6  CA-2017-131254  19/11/2017  21/11/2017     First Class    NC-18415
# 7  CA-2015-116638  28/01/2015         NaN    Second Class    JH-15985
# 8  CA-2016-130946  04/08/2016  04/12/2016  Standard Class    ZC-21910
# 9  CA-2014-145317  18/03/2014  23/03/2014  Standard Class    SM-20320
#
#       Customer Name      Segment        Country          City           State  \
# 0     Cindy Stewart     Consumer  United States     Lancaster            Ohio
# 1    Grant Thornton    Corporate  United States    Burlington  North Carolina
# 2       Luke Foster     Consumer  United States   San Antonio           Texas
# 3    Sharelle Roach  Home Office  United States    Louisville        Colorado
# 4     Henry Goldwyn    Corporate  United States       Chicago        Illinois
# 5  Natalie Fritzler     Consumer  United States        Newark            Ohio
# 6       Nathan Cano     Consumer  United States       Houston           Texas
# 7       Joseph Holt     Consumer  United States       Concord  North Carolina
# 8  Zuschuss Carroll     Consumer  United States       Houston           Texas
# 9       Sean Miller  Home Office            NaN  Jacksonville         Florida
#
#   Postal Code   Region       Product ID         Category Sub-Category  \
# 0       43130      Est  TEC-MA-10000418       Technology     Machines
# 1     "27217"    South  TEC-MA-10004125       Technology     Machines
# 2       78207  Central  OFF-BI-10004995  Office Supplies      Binders
# 3       80027     West  TEC-MA-10000822       Technology     Machines
# 4       60653  Central  OFF-BI-10001120  Office Supplies      Binders
# 5       43055     East  TEC-MA-10000418       Technology     Machines
# 6       77095  Central  OFF-BI-10003527  Office Supplies      Binders
# 7       28027    South  FUR-TA-10000198          Frnture       Tables
# 8       77041  Central  OFF-BI-10004995  Office Supplies      Binders
# 9       32216   Southh  TEC-MA-10002412       Technology     Machines
#
#                                         Product Name      Sales  Quantity  \
# 0          Cubify CubeX 3D Printer Double Head Print   4499.985       5.0
# 1          Cubify CubeX 3D Printer Triple Head Print   7999.980       4.0
# 2          GBC DocuBind P400 Electric Binding System   2177.584       8.0
# 3          Lexmark MX611dhe Monochrome Laser Printer   2549.985       5.0
# 4               Ibico EPK-21 Electric Binding System   1889.990       5.0
# 5          Cubify CubeX 3D Printer Double Head Print   1799.994       2.0
# 6  Fellowes PB500 Electric Punch Plastic Comb Bin...   1525.188       6.0
# 7  Chromcraft Bull-Nose Wood Oval Conference Tabl...   4297.644      13.0
# 8          GBC DocuBind P400 Electric Binding System   1088.792       4.0
# 9  Cisco TelePresence System EX90 Videoconferenci...  22638.480       6.0
#
#    Discount     Profit
# 0       0.7 -6599.9780
# 1       0.5 -3839.9904
# 2       0.8 -3701.8928
# 3       0.7 -3399.9800
# 4       0.8 -2929.4845
# 5       0.7 -2639.9912
# 6       0.8 -2287.7820
# 7       0.4     0.0000
# 8       0.8 -1850.9464
# 9       0.5 -1811.0784

# %%
columns_to_describe.describe()
# Out:
#               Sales   Quantity   Discount       Profit
# count     10.000000  10.000000  10.000000    10.000000
# mean    5046.762200   5.800000   0.670000 -2906.112370
# std     6515.707357   2.973961   0.149443  1719.354081
# min     1088.792000   2.000000   0.400000 -6599.978000
# 25%     1822.493000   4.250000   0.550000 -3626.414600
# 50%     2363.784500   5.000000   0.700000 -2784.737850
# 75%     4449.399750   6.000000   0.800000 -1960.155300
# max    22638.480000  13.000000   0.800000     0.000000
